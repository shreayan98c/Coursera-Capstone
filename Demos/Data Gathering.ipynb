# %% [markdown]
# # A recommendation system for setting up a new restaurant / eatery focussed primarily on the corporate demographic (based on employee count and location of corporate offices in Bangalore, India)

# %% [markdown]
# ## Brief Introduction

# %% [markdown]
# ## Part 1: Description of problem

# %% [markdown]
# ### India is an extremely densely populated country (one of the most dense), with more than 1.34 billion residents.
# ### Obviously it is difficult to start a business here due to high real estate costs.
# ### So, an entrepreneur aiming at a corporate centric market should know the best places to set up shop.

# %% [markdown]
# ### A large population of Bangalore lies in this corporate demographic (more than 200 corporations), and 800+ startups, so eating snack foods out is more popular and convenient than ever, hence goal is to find the best places in Bangalore to setup a new food shop/ restaurant.
# ### The example chosen is for Bangalore, but this project can be used for various different locations like Chennai, Mumbai, Delhi etc.

# %% [markdown]
# ### The objective is to find the optimal location for setting up a new business (based on location of offices, eateries in Bangalore, India).

# %% [markdown]
# ### Target audience:
# ### Entrepreneurs and small-scale businessmen/women interested in the food/ snacks industry, aiming at the corporate demographic for maximising profits.

# %% [markdown]
#  #

# %% [markdown]
# ## Part 2: Data that is needed

# %% [markdown]
# ### 1. We need a list of the corporate offices in Bangalore. Their latitude and longitude will be calculated using Geopy Nominatim (a Python Library).
#
# This data can be found on Wikipedia, as well as many other websites.
#
# For instance: https://en.wikipedia.org/wiki/Category:Companies_based_in_Bangalore

# %% [markdown]
# ### 2. **Then we can use the FourSquare API to find the number of eateries in a 1km radius around each office.** The API will provide us with Postal Code, Neighborhood, Venue, Venue Summary and Venue Category.
#
# Foursquare is a local search-and-discovery service mobile app which provides search results for its users (Wikipedia). It has more than 60 million users.

# %% [markdown]
# ### 3. Processing the Retrieved data and creating a structured DataFrame for all the venues, grouped by offices.

# %% [markdown]
# ### 4. Selecting relevant venues (food related only).
#
# ### **The offices with highest ratio of `(no. of employees)/(no. of eateries)` would be the best places to start a restaurant.** (supply and demand)
#
# We can also create clusters of most highly student populated areas

# %%
import requests  # library to handle requests
import pandas as pd  # library for data analsysis
import numpy as np  # library to handle data in a vectorized manner
import random  # library for random number generation

# module to convert an address into latitude and longitude values
from geopy.geocoders import Nominatim

# libraries for displaying images
from IPython.display import Image
from IPython.core.display import HTML

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
import folium  # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = '1NW3OMZEIVJXCFGGIYLXLLH4CQWIYX3GSO4ERVDST4FXYI4E'  # your Foursquare ID
# your Foursquare Secret
CLIENT_SECRET = 'NNWGYNG2RFCIPLNG0ER4BNC15GPE2CSY10UA32BJFCBYOO0Y'
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 1NW3OMZEIVJXCFGGIYLXLLH4CQWIYX3GSO4ERVDST4FXYI4E
# CLIENT_SECRET:NNWGYNG2RFCIPLNG0ER4BNC15GPE2CSY10UA32BJFCBYOO0Y

# %%
# Amazon Development Center, Aquila building
geolocator = Nominatim(user_agent='myapplication')
location = geolocator.geocode("Amazon Bangalore India").raw
lat = location['lat']
lon = location['lon']
print("Latitude: ", lat)
print("Longitude: ", lon)
# Out:
# Latitude:  12.9795028
# Longitude:  77.6959454

# %%
radius = 1000
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID,
    CLIENT_SECRET,
    VERSION,
    lat,
    lon,
    radius,
    100)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=1NW3OMZEIVJXCFGGIYLXLLH4CQWIYX3GSO4ERVDST4FXYI4E&client_secret=NNWGYNG2RFCIPLNG0ER4BNC15GPE2CSY10UA32BJFCBYOO0Y&v=20180604&ll=12.9795028,77.6959454&radius=1000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5dda6862e826ac0022d64225'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'totalResults': 27,
#   'suggestedBounds': {'ne': {'lat': 12.988502809000009,
#     'lng': 77.70516413934406},
#    'sw': {'lat': 12.970502790999992, 'lng': 77.68672666065594}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be967c2aecb76b073c95a80',
#        'name': 'Jalsa',
#        'location': {'address': 'Doddanekundi',
#         'crossStreet': 'at Outer Ring Rd.',
#         'lat': 12.97768337190332,
#         'lng': 77.6954755254431,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.97768337190332,
#           'lng': 77.6954755254431}],
#         'distance': 208,
#         'postalCode': '560037',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Doddanekundi (at Outer Ring Rd.)',
#          'Bangalore 560037',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be967c2aecb76b073c95a80-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '533137e9498e942664288c93',
#        'name': 'X-Torque',
#        'location': {'address': '329, 4th Cross Rd, HRBR Layout 3rd Block, HRBR Layout',
#         'crossStreet': 'Outer Ring Rd',
#         'lat': 12.977570175403066,
#         'lng': 77.69348269553484,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.977570175403066,
#           'lng': 77.69348269553484}],
#         'distance': 343,
#         'postalCode': '560043',
#         'cc': 'IN',
#         'neighborhood': 'Kalyan Nagar',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['329, 4th Cross Rd, HRBR Layout 3rd Block, HRBR Layout (Outer Ring Rd)',
#          'Bangalore 560043',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '5032833091d4c4b30a586d60',
#          'name': 'Motorcycle Shop',
#          'pluralName': 'Motorcycle Shops',
#          'shortName': 'Motorcycle Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/motorcycle_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-533137e9498e942664288c93-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f805d27e4b0acccb7ef6bd9',
#        'name': 'Kabab Magic',
#        'location': {'address': '39/5, Outer Ring Road,Doddanekundi opp. Total Mall',
#         'lat': 12.978704486487107,
#         'lng': 77.6955324411392,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.978704486487107,
#           'lng': 77.6955324411392}],
#         'distance': 99,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['39/5, Outer Ring Road,Doddanekundi opp. Total Mall',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f805d27e4b0acccb7ef6bd9-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52bbec6511d25c4c5442704e',
#        'name': 'Subway',
#        'location': {'address': 'Food Court, Soulspace Arena',
#         'crossStreet': 'Outer Ring Road, Doddanakundi',
#         'lat': 12.980264900489397,
#         'lng': 77.69409454746737,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.980264900489397,
#           'lng': 77.69409454746737}],
#         'distance': 217,
#         'postalCode': '560048',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Food Court, Soulspace Arena (Outer Ring Road, Doddanakundi)',
#          'Bangalore 560048',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52bbec6511d25c4c5442704e-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57b1ed3a498e1e1493a2fe88',
#        'name': 'Flechazo',
#        'location': {'address': 'Sy No. 9/1, 1st Floor, VRR Orchid, Above Surya Nissan Showroom,, Doddanekkundi',
#         'lat': 12.974379037496897,
#         'lng': 77.69740013340697,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.974379037496897,
#           'lng': 77.69740013340697}],
#         'distance': 591,
#         'postalCode': '560037',
#         'cc': 'IN',
#         'neighborhood': 'Marathalli',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Sy No. 9/1, 1st Floor, VRR Orchid, Above Surya Nissan Showroom,, Doddanekkundi',
#          'Bangalore 560037',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57b1ed3a498e1e1493a2fe88-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58049b5238fac00515703729',
#        'name': 'Subway',
#        'location': {'lat': 12.985817,
#         'lng': 77.6944,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.985817,
#           'lng': 77.6944}],
#         'distance': 722,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Bangalore', 'Karnātaka', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58049b5238fac00515703729-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51d947a0498e71690b63ded3',
#        'name': 'Cafe Coffee Day',
#        'location': {'address': 'Opposite To EMC2',
#         'crossStreet': 'Doddanekundi',
#         'lat': 12.979549808570274,
#         'lng': 77.69434613422327,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.979549808570274,
#           'lng': 77.69434613422327}],
#         'distance': 173,
#         'postalCode': '560037',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Opposite To EMC2 (Doddanekundi)',
#          'Bangalore 560037',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51d947a0498e71690b63ded3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ee1fd999adf48bc1993f358',
#        'name': 'CineMAX',
#        'location': {'address': '5th Flr, Soul Space Arena Mall Service Rd, B Chinappa Layout, Doddanekkundi',
#         'crossStreet': 'Outer Ring Road, Doddanekundi',
#         'lat': 12.979686530427296,
#         'lng': 77.69391005015251,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.979686530427296,
#           'lng': 77.69391005015251}],
#         'distance': 221,
#         'postalCode': '560037',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['5th Flr, Soul Space Arena Mall Service Rd, B Chinappa Layout, Doddanekkundi (Outer Ring Road, Doddanekundi)',
#          'Bangalore 560037',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d180941735',
#          'name': 'Multiplex',
#          'pluralName': 'Multiplexes',
#          'shortName': 'Cineplex',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ee1fd999adf48bc1993f358-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51d6ca7e498ec1553d50b8d8',
#        'name': 'Cafe Coffee Day',
#        'location': {'lat': 12.982808108506525,
#         'lng': 77.69389886848724,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.982808108506525,
#           'lng': 77.69389886848724}],
#         'distance': 429,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51d6ca7e498ec1553d50b8d8-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e048e52483b6f89f47e2e6c',
#        'name': 'Callista Bar & Kitchen',
#        'location': {'address': 'No 38/3, Opposite EMC,',
#         'crossStreet': 'Doddanakundi, Outer Ring Road',
#         'lat': 12.980595589219849,
#         'lng': 77.69348810593283,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.980595589219849,
#           'lng': 77.69348810593283}],
#         'distance': 293,
#         'postalCode': '560037',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['No 38/3, Opposite EMC, (Doddanakundi, Outer Ring Road)',
#          'Bangalore 560037',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4d4b7105d754a06374d81259',
#          'name': 'Food',
#          'pluralName': 'Food',
#          'shortName': 'Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e048e52483b6f89f47e2e6c-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '516288fde4b082d0c0d3eb37',
#        'name': 'spree hotels',
#        'location': {'address': 'total mall',
#         'crossStreet': 'soul space arena',
#         'lat': 12.978960706711176,
#         'lng': 77.69455858481979,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.978960706711176,
#           'lng': 77.69455858481979}],
#         'distance': 162,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['total mall (soul space arena)',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-516288fde4b082d0c0d3eb37-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '587394c1727ba307bf9491a8',
#        'name': 'Sarovar Portico',
#        'location': {'lat': 12.978899,
#         'lng': 77.69456,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.978899,
#           'lng': 77.69456}],
#         'distance': 164,
#         'postalCode': '560037',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Bangalore 560037', 'Karnātaka', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-587394c1727ba307bf9491a8-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51caf4f4498ea8074eeff11e',
#        'name': 'cinemax, soul space arena',
#        'location': {'address': 'Soul space arena,',
#         'crossStreet': 'Outer Ring road',
#         'lat': 12.979033141440048,
#         'lng': 77.69329505689967,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.979033141440048,
#           'lng': 77.69329505689967}],
#         'distance': 292,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Soul space arena, (Outer Ring road)',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51caf4f4498ea8074eeff11e-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '512e3c6ae4b0126abf05a497',
#        'name': 'Hind Ka Chulha',
#        'location': {'lat': 12.980291349966294,
#         'lng': 77.69347396437736,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.980291349966294,
#           'lng': 77.69347396437736}],
#         'distance': 282,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-512e3c6ae4b0126abf05a497-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cfde38fc6cca35d463e9932',
#        'name': 'EMC India Cafeteria',
#        'location': {'address': 'Mahadevapura',
#         'crossStreet': 'KR Puram-Marathahalli Ring Road',
#         'lat': 12.981725891739579,
#         'lng': 77.69406795501709,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.981725891739579,
#           'lng': 77.69406795501709}],
#         'distance': 320,
#         'postalCode': '560048',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Mahadevapura (KR Puram-Marathahalli Ring Road)',
#          'Bangalore 560048',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d128941735',
#          'name': 'Cafeteria',
#          'pluralName': 'Cafeterias',
#          'shortName': 'Cafeteria',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cfde38fc6cca35d463e9932-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56f0f99f498e998cd93b78a6',
#        'name': 'The Brew and Barbeque',
#        'location': {'address': 'Soulspace Arena Mall 36/5, 4th Floor Outter Ring Road, Doddanekunddi',
#         'lat': 12.979946025888285,
#         'lng': 77.692965894289,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.979946025888285,
#           'lng': 77.692965894289}],
#         'distance': 326,
#         'cc': 'IN',
#         'neighborhood': 'Mahadevapura',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Soulspace Arena Mall 36/5, 4th Floor Outter Ring Road, Doddanekunddi',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56f0f99f498e998cd93b78a6-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '548fe082498e6c9bcb3803ab',
#        'name': '3 Kings Cafe',
#        'location': {'lat': 12.976808450830811,
#         'lng': 77.69285896872105,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.976808450830811,
#           'lng': 77.69285896872105}],
#         'distance': 449,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-548fe082498e6c9bcb3803ab-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '580f04ef38fa7cd8e4fee90b',
#        'name': 'Accenture',
#        'location': {'address': 'Bagmane Developers Pvt Ltd SEZ-II, Marathalli Ring Road, KR Puram Hobli, Doddanekundi Village',
#         'crossStreet': 'doddanekundi',
#         'lat': 12.985550721648488,
#         'lng': 77.69524474451623,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.985550721648488,
#           'lng': 77.69524474451623}],
#         'distance': 677,
#         'postalCode': '560048',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Bagmane Developers Pvt Ltd SEZ-II, Marathalli Ring Road, KR Puram Hobli, Doddanekundi Village (doddanekundi)',
#          'Bangalore 560048',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '5453de49498eade8af355881',
#          'name': 'Business Service',
#          'pluralName': 'Business Services',
#          'shortName': 'Business Services',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-580f04ef38fa7cd8e4fee90b-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56a8b99e498e21f1a9dc62df',
#        'name': 'Hunan Express',
#        'location': {'address': 'Ground Floor, Onyx',
#         'lat': 12.985786415359756,
#         'lng': 77.69492198621809,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.985786415359756,
#           'lng': 77.69492198621809}],
#         'distance': 708,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['Ground Floor, Onyx', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56a8b99e498e21f1a9dc62df-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56aa0b86498e1525f2661c32',
#        'name': 'California Burrito',
#        'location': {'address': 'Food court, Bagmane World Technology Centre',
#         'crossStreet': 'Food Court',
#         'lat': 12.985807163353885,
#         'lng': 77.69489403230641,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.985807163353885,
#           'lng': 77.69489403230641}],
#         'distance': 711,
#         'postalCode': '560048',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Food court, Bagmane World Technology Centre (Food Court)',
#          'Bangalore 560048',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d153941735',
#          'name': 'Burrito Place',
#          'pluralName': 'Burrito Places',
#          'shortName': 'Burritos',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56aa0b86498e1525f2661c32-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '560d30f4498e9a988b1815a5',
#        'name': 'Food Court',
#        'location': {'address': 'Onyx, Bagmane World Technology Centre',
#         'lat': 12.98597873167466,
#         'lng': 77.69427460046917,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.98597873167466,
#           'lng': 77.69427460046917}],
#         'distance': 743,
#         'postalCode': '560048',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Onyx, Bagmane World Technology Centre',
#          'Bangalore 560048',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d128941735',
#          'name': 'Cafeteria',
#          'pluralName': 'Cafeterias',
#          'shortName': 'Cafeteria',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-560d30f4498e9a988b1815a5-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fd94bdde4b0a2110cf69c73',
#        'name': 'Alpine Mart super market',
#        'location': {'address': 'Inside alpine eco apartments',
#         'crossStreet': 'nekundi',
#         'lat': 12.974003623548185,
#         'lng': 77.7009990003061,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.974003623548185,
#           'lng': 77.7009990003061}],
#         'distance': 821,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['Inside alpine eco apartments (nekundi)',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fd94bdde4b0a2110cf69c73-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50dc8cb4e4b0e32046d02333',
#        'name': 'Alpine Eco Joggers Track',
#        'location': {'lat': 12.973116401318523,
#         'lng': 77.7001696753979,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.973116401318523,
#           'lng': 77.7001696753979}],
#         'distance': 845,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50dc8cb4e4b0e32046d02333-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50b1b463e4b037e0ed6138f0',
#        'name': 'Dial A Chaat',
#        'location': {'address': 'Marathahalli',
#         'lat': 12.973583624735237,
#         'lng': 77.70131206657868,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.973583624735237,
#           'lng': 77.70131206657868}],
#         'distance': 879,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Marathahalli',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50b1b463e4b037e0ed6138f0-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f0fbcd1e4b0297e548793d8',
#        'name': 'mahadevpura bus stop',
#        'location': {'lat': 12.987428686795216,
#         'lng': 77.69451385841204,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.987428686795216,
#           'lng': 77.69451385841204}],
#         'distance': 895,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f0fbcd1e4b0297e548793d8-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50745750e4b0531e5c56fec0',
#        'name': 'Gateway super Bazar',
#        'location': {'address': 'Next to Alpine Eco',
#         'lat': 12.972868069874243,
#         'lng': 77.70082569538432,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.972868069874243,
#           'lng': 77.70082569538432}],
#         'distance': 908,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['Next to Alpine Eco', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50745750e4b0531e5c56fec0-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bfb6b98d2b720a18d03336a',
#        'name': 'More Mega Store',
#        'location': {'lat': 12.986378152464317,
#         'lng': 77.69108664410004,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.986378152464317,
#           'lng': 77.69108664410004}],
#         'distance': 929,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bfb6b98d2b720a18d03336a-26'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']

    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']

nearby_venues = json_normalize(venues)  # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories',
                    'venue.location.lat', 'venue.location.lng']
nearby_venues = nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(
    get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
print(nearby_venues.shape)
nearby_venues
# Out:
# (27, 4)
#                          name                categories        lat        lng
# 0                       Jalsa         Indian Restaurant  12.977683  77.695476
# 1                    X-Torque           Motorcycle Shop  12.977570  77.693483
# 2                 Kabab Magic       Fried Chicken Joint  12.978704  77.695532
# 3                      Subway            Sandwich Place  12.980265  77.694095
# 4                    Flechazo  Mediterranean Restaurant  12.974379  77.697400
# 5                      Subway            Sandwich Place  12.985817  77.694400
# 6             Cafe Coffee Day               Coffee Shop  12.979550  77.694346
# 7                     CineMAX                 Multiplex  12.979687  77.693910
# 8             Cafe Coffee Day               Coffee Shop  12.982808  77.693899
# 9      Callista Bar & Kitchen                      Food  12.980596  77.693488
# 10               spree hotels         Indian Restaurant  12.978961  77.694559
# 11            Sarovar Portico                     Hotel  12.978899  77.694560
# 12  cinemax, soul space arena             Movie Theater  12.979033  77.693295
# 13             Hind Ka Chulha         Indian Restaurant  12.980291  77.693474
# 14        EMC India Cafeteria                 Cafeteria  12.981726  77.694068
# 15      The Brew and Barbeque                 BBQ Joint  12.979946  77.692966
# 16               3 Kings Cafe                      Café  12.976808  77.692859
# 17                  Accenture          Business Service  12.985551  77.695245
# 18              Hunan Express        Chinese Restaurant  12.985786  77.694922
# 19         California Burrito             Burrito Place  12.985807  77.694894
# 20                 Food Court                 Cafeteria  12.985979  77.694275
# 21   Alpine Mart super market          Department Store  12.974004  77.700999
# 22   Alpine Eco Joggers Track                      Park  12.973116  77.700170
# 23               Dial A Chaat            Breakfast Spot  12.973584  77.701312
# 24       mahadevpura bus stop               Bus Station  12.987429  77.694514
# 25        Gateway super Bazar          Department Store  12.972868  77.700826
# 26            More Mega Store          Department Store  12.986378  77.691087

# %%
nearby_venues.categories.unique()
# Out:
# array(['Indian Restaurant', 'Motorcycle Shop', 'Fried Chicken Joint',
#        'Sandwich Place', 'Mediterranean Restaurant', 'Coffee Shop',
#        'Multiplex', 'Food', 'Hotel', 'Movie Theater', 'Cafeteria',
#        'BBQ Joint', 'Café', 'Business Service', 'Chinese Restaurant',
#        'Burrito Place', 'Department Store', 'Park', 'Breakfast Spot',
#        'Bus Station'], dtype=object)

# %% [markdown]
# ### Listing the offices we will study

# %%
offices = ['Amazon','Infosys','Dell','HP','Tech Mahindra','SAP','Samsung R&D','Accenture','Wipro','TCS', 'IBM','Oracle',
           'Cognizant','Capgemini','Cisco','Mindtree','HCL','Mu Sigma','Robert Bosch','Thomson Reuters','Honeywell','CGI',
           'Mphasis','EY','Deloitte','Nokia','Intel','Huawei','Goldman Sachs','Flipkart']
print(len(offices))
# Out:
# 30

# %% [markdown]
# Adding Bangalore to the end of each to help Nominatim find the coordinates for the locations more easily

# %%
offices = [x+" Bangalore" for x in offices]
offices
# Out:
# ['Amazon Bangalore',
#  'Infosys Bangalore',
#  'Dell Bangalore',
#  'HP Bangalore',
#  'Tech Mahindra Bangalore',
#  'SAP Bangalore',
#  'Samsung R&D Bangalore',
#  'Accenture Bangalore',
#  'Wipro Bangalore',
#  'TCS Bangalore',
#  'IBM Bangalore',
#  'Oracle Bangalore',
#  'Cognizant Bangalore',
#  'Capgemini Bangalore',
#  'Cisco Bangalore',
#  'Mindtree Bangalore',
#  'HCL Bangalore',
#  'Mu Sigma Bangalore',
#  'Robert Bosch Bangalore',
#  'Thomson Reuters Bangalore',
#  'Honeywell Bangalore',
#  'CGI Bangalore',
#  'Mphasis Bangalore',
#  'EY Bangalore',
#  'Deloitte Bangalore',
#  'Nokia Bangalore',
#  'Intel Bangalore',
#  'Huawei Bangalore',
#  'Goldman Sachs Bangalore',
#  'Flipkart Bangalore']

# %% [markdown]
# ### Function to get latitude and longitude of each office

# %%
def coords(office):
    d = {}
    d['office'] = office
    geolocator = Nominatim(user_agent='myapplication')
    try:
        location = geolocator.geocode(office).raw
        d['latitude'] = location['lat']
        d['longitude'] = location['lon']
        return d
    except Exception as e:
        print("Office %s not found"%office)
        return -1

# %%
l = []
for i in offices:
    details = coords(i)
    if(details!=-1):
        l.append(coords(i))
print(l)
print(len(l))
# Out:
# Office Mphasis Bangalore not found
# Office Goldman Sachs Bangalore not found
# [{'office': 'Amazon Bangalore', 'latitude': '12.9795028', 'longitude': '77.6959454'}, {'office': 'Infosys Bangalore', 'latitude': '12.84508845', 'longitude': '77.6649530443891'}, {'office': 'Dell Bangalore', 'latitude': '12.9383649', 'longitude': '77.629499'}, {'office': 'HP Bangalore', 'latitude': '12.99646925', 'longitude': '77.6888267135983'}, {'office': 'Tech Mahindra Bangalore', 'latitude': '12.85094555', 'longitude': '77.6778630567074'}, {'office': 'SAP Bangalore', 'latitude': '12.9608001', 'longitude': '77.6372345'}, {'office': 'Samsung R&D Bangalore', 'latitude': '13.0043687', 'longitude': '77.5524019'}, {'office': 'Accenture Bangalore', 'latitude': '12.9678934', 'longitude': '77.7240130513179'}, {'office': 'Wipro Bangalore', 'latitude': '12.9135669', 'longitude': '77.6856346215575'}, {'office': 'TCS Bangalore', 'latitude': '12.84830835', 'longitude': '77.6789892079896'}, {'office': 'IBM Bangalore', 'latitude': '13.0495985', 'longitude': '77.6213264'}, {'office': 'Oracle Bangalore', 'latitude': '12.9306794', 'longitude': '77.6100855552236'}, {'office': 'Cognizant Bangalore', 'latitude': '12.97941415', 'longitude': '77.6635424073171'}, {'office': 'Capgemini Bangalore', 'latitude': '12.9928713', 'longitude': '77.7034566'}, {'office': 'Cisco Bangalore', 'latitude': '12.9314394', 'longitude': '77.6913134'}, {'office': 'Mindtree Bangalore', 'latitude': '12.91834955', 'longitude': '77.5020134870256'}, {'office': 'HCL Bangalore', 'latitude': '12.9839629', 'longitude': '77.7331651641726'}, {'office': 'Mu Sigma Bangalore', 'latitude': '12.95759155', 'longitude': '77.7441904089781'}, {'office': 'Robert Bosch Bangalore', 'latitude': '12.9265276', 'longitude': '77.6798083'}, {'office': 'Thomson Reuters Bangalore', 'latitude': '12.9476359', 'longitude': '77.6893826226266'}, {'office': 'Honeywell Bangalore', 'latitude': '12.91959615', 'longitude': '77.6861506506649'}, {'office': 'CGI Bangalore', 'latitude': '12.9483819', 'longitude': '77.6892497'}, {'office': 'EY Bangalore', 'latitude': '12.9799633', 'longitude': '77.6959069'}, {'office': 'Deloitte Bangalore', 'latitude': '12.9864631', 'longitude': '77.5876251'}, {'office': 'Nokia Bangalore', 'latitude': '13.051238', 'longitude': '77.6202024'}, {'office': 'Intel Bangalore', 'latitude': '12.9273327', 'longitude': '77.684308404235'}, {'office': 'Huawei Bangalore', 'latitude': '12.96924415', 'longitude': '77.7268358'}, {'office': 'Flipkart Bangalore', 'latitude': '12.9283777', 'longitude': '77.6327535755866'}]
# 28

# %% [markdown]
# Latitude and Longitude of Bangalore, India

# %%
ban_lat = 12.9716
ban_lon = 77.5946

# %% [markdown]
# #### Plotting all the institutes that we are considering

# %%
office_map = folium.Map(location = [ban_lat, ban_lon], zoom_start=12)

for d in l:
    folium.CircleMarker(
    [float(d['latitude']), float(d['longitude'])],
        radius = 5, 
        popup = d['office'],
        fill = True,
        color = '#0012EE',
        fill_color = 'red',
        fill_opacity = 0.5
    ).add_to(office_map)
    
office_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Food related categories

# %%
food_cats = ['Ice Cream Shop', 'Sandwich Place', 'Food Truck', 'Fast Food Restaurant', 'Indian Restaurant', 'Steakhouse',
            'Chinese Restaurant', 'Coffee Shop', 'Bakery', 'Café', 'Middle Eastern Restuarant']

# %% [markdown]
# Testing plot for nearby venues for Amazon

# %%
print(l[0])
office1 = l[0]['office']
lat = l[0]['latitude']
lon = l[0]['longitude']
# Out:
# {'office': 'Amazon Bangalore', 'latitude': '12.9795028', 'longitude': '77.6959454'}

# %%
radius = 500
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID,
    CLIENT_SECRET,
    VERSION,
    lat,
    lon,
    radius,
    100)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=1NW3OMZEIVJXCFGGIYLXLLH4CQWIYX3GSO4ERVDST4FXYI4E&client_secret=NNWGYNG2RFCIPLNG0ER4BNC15GPE2CSY10UA32BJFCBYOO0Y&v=20180604&ll=12.9795028,77.6959454&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5dda68ba78a484001bfd94a8'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'totalResults': 15,
#   'suggestedBounds': {'ne': {'lat': 12.984002804500005,
#     'lng': 77.70055476967202},
#    'sw': {'lat': 12.975002795499996, 'lng': 77.69133603032797}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be967c2aecb76b073c95a80',
#        'name': 'Jalsa',
#        'location': {'address': 'Doddanekundi',
#         'crossStreet': 'at Outer Ring Rd.',
#         'lat': 12.97768337190332,
#         'lng': 77.6954755254431,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.97768337190332,
#           'lng': 77.6954755254431}],
#         'distance': 208,
#         'postalCode': '560037',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Doddanekundi (at Outer Ring Rd.)',
#          'Bangalore 560037',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be967c2aecb76b073c95a80-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '533137e9498e942664288c93',
#        'name': 'X-Torque',
#        'location': {'address': '329, 4th Cross Rd, HRBR Layout 3rd Block, HRBR Layout',
#         'crossStreet': 'Outer Ring Rd',
#         'lat': 12.977570175403066,
#         'lng': 77.69348269553484,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.977570175403066,
#           'lng': 77.69348269553484}],
#         'distance': 343,
#         'postalCode': '560043',
#         'cc': 'IN',
#         'neighborhood': 'Kalyan Nagar',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['329, 4th Cross Rd, HRBR Layout 3rd Block, HRBR Layout (Outer Ring Rd)',
#          'Bangalore 560043',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '5032833091d4c4b30a586d60',
#          'name': 'Motorcycle Shop',
#          'pluralName': 'Motorcycle Shops',
#          'shortName': 'Motorcycle Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/motorcycle_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-533137e9498e942664288c93-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f805d27e4b0acccb7ef6bd9',
#        'name': 'Kabab Magic',
#        'location': {'address': '39/5, Outer Ring Road,Doddanekundi opp. Total Mall',
#         'lat': 12.978704486487107,
#         'lng': 77.6955324411392,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.978704486487107,
#           'lng': 77.6955324411392}],
#         'distance': 99,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['39/5, Outer Ring Road,Doddanekundi opp. Total Mall',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f805d27e4b0acccb7ef6bd9-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52bbec6511d25c4c5442704e',
#        'name': 'Subway',
#        'location': {'address': 'Food Court, Soulspace Arena',
#         'crossStreet': 'Outer Ring Road, Doddanakundi',
#         'lat': 12.980264900489397,
#         'lng': 77.69409454746737,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.980264900489397,
#           'lng': 77.69409454746737}],
#         'distance': 217,
#         'postalCode': '560048',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Food Court, Soulspace Arena (Outer Ring Road, Doddanakundi)',
#          'Bangalore 560048',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52bbec6511d25c4c5442704e-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51d947a0498e71690b63ded3',
#        'name': 'Cafe Coffee Day',
#        'location': {'address': 'Opposite To EMC2',
#         'crossStreet': 'Doddanekundi',
#         'lat': 12.979549808570274,
#         'lng': 77.69434613422327,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.979549808570274,
#           'lng': 77.69434613422327}],
#         'distance': 173,
#         'postalCode': '560037',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Opposite To EMC2 (Doddanekundi)',
#          'Bangalore 560037',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51d947a0498e71690b63ded3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ee1fd999adf48bc1993f358',
#        'name': 'CineMAX',
#        'location': {'address': '5th Flr, Soul Space Arena Mall Service Rd, B Chinappa Layout, Doddanekkundi',
#         'crossStreet': 'Outer Ring Road, Doddanekundi',
#         'lat': 12.979686530427296,
#         'lng': 77.69391005015251,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.979686530427296,
#           'lng': 77.69391005015251}],
#         'distance': 221,
#         'postalCode': '560037',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['5th Flr, Soul Space Arena Mall Service Rd, B Chinappa Layout, Doddanekkundi (Outer Ring Road, Doddanekundi)',
#          'Bangalore 560037',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d180941735',
#          'name': 'Multiplex',
#          'pluralName': 'Multiplexes',
#          'shortName': 'Cineplex',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ee1fd999adf48bc1993f358-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51d6ca7e498ec1553d50b8d8',
#        'name': 'Cafe Coffee Day',
#        'location': {'lat': 12.982808108506525,
#         'lng': 77.69389886848724,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.982808108506525,
#           'lng': 77.69389886848724}],
#         'distance': 429,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51d6ca7e498ec1553d50b8d8-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '516288fde4b082d0c0d3eb37',
#        'name': 'spree hotels',
#        'location': {'address': 'total mall',
#         'crossStreet': 'soul space arena',
#         'lat': 12.978960706711176,
#         'lng': 77.69455858481979,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.978960706711176,
#           'lng': 77.69455858481979}],
#         'distance': 162,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['total mall (soul space arena)',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-516288fde4b082d0c0d3eb37-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '587394c1727ba307bf9491a8',
#        'name': 'Sarovar Portico',
#        'location': {'lat': 12.978899,
#         'lng': 77.69456,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.978899,
#           'lng': 77.69456}],
#         'distance': 164,
#         'postalCode': '560037',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Bangalore 560037', 'Karnātaka', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-587394c1727ba307bf9491a8-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e048e52483b6f89f47e2e6c',
#        'name': 'Callista Bar & Kitchen',
#        'location': {'address': 'No 38/3, Opposite EMC,',
#         'crossStreet': 'Doddanakundi, Outer Ring Road',
#         'lat': 12.980595589219849,
#         'lng': 77.69348810593283,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.980595589219849,
#           'lng': 77.69348810593283}],
#         'distance': 293,
#         'postalCode': '560037',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['No 38/3, Opposite EMC, (Doddanakundi, Outer Ring Road)',
#          'Bangalore 560037',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4d4b7105d754a06374d81259',
#          'name': 'Food',
#          'pluralName': 'Food',
#          'shortName': 'Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e048e52483b6f89f47e2e6c-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51caf4f4498ea8074eeff11e',
#        'name': 'cinemax, soul space arena',
#        'location': {'address': 'Soul space arena,',
#         'crossStreet': 'Outer Ring road',
#         'lat': 12.979033141440048,
#         'lng': 77.69329505689967,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.979033141440048,
#           'lng': 77.69329505689967}],
#         'distance': 292,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Soul space arena, (Outer Ring road)',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51caf4f4498ea8074eeff11e-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '512e3c6ae4b0126abf05a497',
#        'name': 'Hind Ka Chulha',
#        'location': {'lat': 12.980291349966294,
#         'lng': 77.69347396437736,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.980291349966294,
#           'lng': 77.69347396437736}],
#         'distance': 282,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-512e3c6ae4b0126abf05a497-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cfde38fc6cca35d463e9932',
#        'name': 'EMC India Cafeteria',
#        'location': {'address': 'Mahadevapura',
#         'crossStreet': 'KR Puram-Marathahalli Ring Road',
#         'lat': 12.981725891739579,
#         'lng': 77.69406795501709,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.981725891739579,
#           'lng': 77.69406795501709}],
#         'distance': 320,
#         'postalCode': '560048',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Mahadevapura (KR Puram-Marathahalli Ring Road)',
#          'Bangalore 560048',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d128941735',
#          'name': 'Cafeteria',
#          'pluralName': 'Cafeterias',
#          'shortName': 'Cafeteria',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cfde38fc6cca35d463e9932-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56f0f99f498e998cd93b78a6',
#        'name': 'The Brew and Barbeque',
#        'location': {'address': 'Soulspace Arena Mall 36/5, 4th Floor Outter Ring Road, Doddanekunddi',
#         'lat': 12.979946025888285,
#         'lng': 77.692965894289,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.979946025888285,
#           'lng': 77.692965894289}],
#         'distance': 326,
#         'cc': 'IN',
#         'neighborhood': 'Mahadevapura',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Soulspace Arena Mall 36/5, 4th Floor Outter Ring Road, Doddanekunddi',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56f0f99f498e998cd93b78a6-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '548fe082498e6c9bcb3803ab',
#        'name': '3 Kings Cafe',
#        'location': {'lat': 12.976808450830811,
#         'lng': 77.69285896872105,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.976808450830811,
#           'lng': 77.69285896872105}],
#         'distance': 449,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-548fe082498e6c9bcb3803ab-14'}]}]}}

# %% [markdown]
# #### Filtering only food related venues

# %%
venues = results['response']['groups'][0]['items']

nearby_venues = json_normalize(venues)  # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories',
                    'venue.location.lat', 'venue.location.lng']
nearby_venues = nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(
    get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
nearby_venues = nearby_venues[nearby_venues['categories'].isin(food_cats)]
print(nearby_venues.shape)
nearby_venues
# Out:
# (7, 4)
#                name         categories        lat        lng
# 0             Jalsa  Indian Restaurant  12.977683  77.695476
# 3            Subway     Sandwich Place  12.980265  77.694095
# 4   Cafe Coffee Day        Coffee Shop  12.979550  77.694346
# 6   Cafe Coffee Day        Coffee Shop  12.982808  77.693899
# 7      spree hotels  Indian Restaurant  12.978961  77.694559
# 11   Hind Ka Chulha  Indian Restaurant  12.980291  77.693474
# 14     3 Kings Cafe               Café  12.976808  77.692859

# %%
venues_i1 = []
for index, row in nearby_venues.iterrows():
    d = {}
    d['name'] = row['name']
    d['lat'] = row['lat']
    d['lng'] = row['lng']
    venues_i1.append(d)

# %% [markdown]
# #### Plotting the food venues near Amazon

# %%
rest_map = folium.Map(location=[float(lat), float(lon)], zoom_start=15)

for d in venues_i1:
    folium.CircleMarker(
        [float(d['lat']), float(d['lng'])],
        radius=5,
        popup=d['name'],
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.5
    ).add_to(rest_map)

folium.CircleMarker(
    [float(lat), float(lon)],
    radius=7.5,
    popup=office1,
    fill=True,
    color='red',
    fill_color='red'
).add_to(rest_map)
rest_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
